# %% [markdown]
# #Juego 7 y medio

# %%
import random
cartas=[
    ("As oros",1),
    ("2 oros",2),
    ("3 oros",3),
    ("4 oros",4),
    ("5 oros",5),
    ("6 oros",6),
    ("7 oros",7),
    ("10 oros",0.5),
    ("11 oros",0.5),
    ("12 oros",0.5),
    ("As copas",1),
    ("2 copas",2),
    ("3 copas",3),
    ("4 copas",4),
    ("5 copas",5),
    ("6 copas",6),
    ("7 copas",7),
    ("10 copas",0.5),
    ("11 copas",0.5),
    ("12 copas",0.5),
    ("As espadas",1),
    ("2 espadas",2),
    ("3 espadas",3),
    ("4 espadas",4),
    ("5 espadas",5),
    ("6 espadas",6),
    ("7 espadas",7),
    ("10 espadas",0.5),
    ("11 espadas",0.5),
    ("12 espadas",0.5),
    ("As bastos",1),
    ("2 bastos",2),
    ("3 bastos",3),
    ("4 bastos",4),
    ("5 bastos",5),
    ("6 bastos",6),
    ("7 bastos",7),
    ("10 bastos",0.5),
    ("11 bastos",0.5),
    ("12 bastos",0.5)
]

pedir_carta=True
#guardar cartas random
cartas_barajeadas=[]

i=0
#barajear
mano_j1=[]
mano_j2=[]

pedir_carta_j1=True
pedir_carta_j2=True
jugadores=[]

puntos_j1=0
puntos_j2=0




while(not cartas==[] and pedir_carta_j1==True or pedir_carta_j2==True):#muentras no este vacia
    #BARAJEAR CARTAS J1
    if(pedir_carta_j1):
        print(cartas_barajeadas.append(cartas.pop(random.randint(0,len(cartas)-1))))
        #traer carta de las cartas barajeadas
        carta=cartas_barajeadas.pop()
        #añadir carta a la lista mano J1
        mano_j1.append(carta)
        puntos_j1=puntos_j1+mano_j1([-1][-1])
        #sumar puntos de cartas
        
    if(int(input("Quieres más cartas sí(1) / no(0)"))):
        carta=cartas_barajeadas.pop()
        #añadir carta a la lista mano J1
        mano_j1.append(carta)
        puntos_j1=puntos_j1+mano_j1([-1][-1])
        #sumar puntos de cartas
    else:
        print(puntos_j1)
        break
        
    #BARAJEAR CARTAS J2
    
     if(pedir_carta_j2):
        print(cartas_barajeadas.append(cartas.pop(random.randint(0,len(cartas)-1))))
        #traer carta de las cartas barajeadas
        carta=cartas_barajeadas.pop()
        #añadir carta a la lista mano J1
        mano_j2.append(carta)
        puntos_j2=puntos_j2+mano_j2([-1][-1])
        #sumar puntos de cartas
        if(puntos_j2>7.5):
            print("jugador 1 ha perdido")
            print(puntos_j1)
        
    if(int(input("Quieres más cartas sí(1) / no(0)"))):
        carta=cartas_barajeadas.pop()
        #añadir carta a la lista mano J1
        mano_j2.append(carta)
        puntos_j2=puntos_j2+mano_j2([-1][-1])
        #sumar puntos de cartas
        if(puntos_j2>7.5):
            print("jugador 1 ha perdido")
            print(puntos_j1)
# Out:
#   Cell In [1], line 43
#     puntos_j1=puntos_j1+
#                         ^
# SyntaxError: invalid syntax

# %%
#decicion de ganador con base en puntos totales
if(puntos_j1<7.5 or puntos_j2<7.5):
    
    if(puntos_j1>7.5 ):
        print(f"jugador 1 pierde con{puntos_j1}, mayor a 7.5")
    else:
        pass
    
    if(puntos_j2>7.5):
        print(f"jugador 2 pierde con{puntos_j2}, mayor a 7.5")
    elif(puntos_j2==7.5 and puntos_j1==7.5):
        print(f"jugador 1 y jugador 2 EMPATAN")
    elif(puntos_j1==puntos_j2 ):
        print("ambos jugadores empatan ")
    
    else:
        pass
        
        
if(puntos_j1 >puntos_j2 and puntos_j1<=7.5):
    print(f"jugador 1 gana con {puntos_j1}")
else:
    if(puntos_j2>puntos_j1 and puntos_j2<=7.5):
        print(f"jugador 2 gana con{puntos_j2}")

# %%
import random
cartas=[
    ("As oros",1),
    ("2 oros",2),
    ("3 oros",3),
    ("4 oros",4),
    ("5 oros",5),
    ("6 oros",6),
    ("7 oros",7),
    ("10 oros",0.5),
    ("11 oros",0.5),
    ("12 oros",0.5),
    ("As copas",1),
    ("2 copas",2),
    ("3 copas",3),
    ("4 copas",4),
    ("5 copas",5),
    ("6 copas",6),
    ("7 copas",7),
    ("10 copas",0.5),
    ("11 copas",0.5),
    ("12 copas",0.5),
    ("As espadas",1),
    ("2 espadas",2),
    ("3 espadas",3),
    ("4 espadas",4),
    ("5 espadas",5),
    ("6 espadas",6),
    ("7 espadas",7),
    ("10 espadas",0.5),
    ("11 espadas",0.5),
    ("12 espadas",0.5),
    ("As bastos",1),
    ("2 bastos",2),
    ("3 bastos",3),
    ("4 bastos",4),
    ("5 bastos",5),
    ("6 bastos",6),
    ("7 bastos",7),
    ("10 bastos",0.5),
    ("11 bastos",0.5),
    ("12 bastos",0.5)
]


pedir_carta=True
#guardar cartas random
cartas_barajeadas=[]

i=0
#barajear
mano_j1=[]
mano_j2=[]

pedir_carta_j1=True
pedir_carta_j2=True
jugadores=[]
entrada_player=True
jugador_nuevo=True
seguir=True
#introducir jugadores y sus nombre
while(entrada_player==True):
    nombre=input("Nombre jugador")
    jugadores.append(nombre)
    
    for intro in jugadores
    print("alguien más va a jugar?")
    jugador_nuevo=str(input("¿Seguir agregando a la CESTA? s/n"))
    if(jugador_nuevo=="n" or jugador_nuevo=="no"):
        seguir==False
        print(f("JUEGADORES{jugadores}")
        break
    



for jugadores in range(len(jugadores)):

    while(pedir_carta_j1==True or pedir_carta_j2==True):
        #for jugadas in range (len(cartas)):
        turno_j1=input("{jugadores}, quieres tra carta?")
        

    

while(not cartas==[] and pedir_carta_j1==True):#muentras no este vacia
    cartas_barajeadas.append(cartas.pop(random.randint(0,len(cartas)-1)))
    
#print(cartas_barajeadas)


    


if(puntos_j1<7.5 or puntos_j2<7.5):
    
    if(puntos_j1<7.5):
        
    if(puntos_j2<7.5):
        
if(puntos_j1 >puntos_j2):
    print("jugador 1 gana con {puntos_j1}")
